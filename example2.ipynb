# %%
from myBdd import *

# %%
f = boolfunc.Expression(
    r"input/1.pcn")
print(f)
# Out:
# 6
# 36
# 6 1 -2 -3 -4 -5 -6
# 6 -1 -2 -3 -4 5 6
# 6 1 -2 3 4 -5 -6
# 6 1 -2 -3 -4 -5 6
# 6 1 -2 3 4 -5 6
# 6 1 2 3 -4 5 -6
# 6 1 -2 -3 4 -5 -6
# 6 1 -2 3 -4 5 -6
# 6 -1 -2 3 -4 5 -6
# 6 1 2 3 -4 5 6
# 6 1 -2 -3 4 -5 6
# 6 -1 -2 3 -4 5 6
# 6 1 -2 3 -4 5 6
# 6 1 2 -3 -4 5 -6
# 6 -1 -2 3 4 5 -6
# 6 -1 -2 -3 -4 -5 -6
# 6 1 -2 -3 -4 5 -6
# 6 1 -2 3 4 5 -6
# 6 1 2 -3 -4 5 6
# 6 -1 -2 3 4 5 6
# 6 1 -2 -3 -4 5 6
# 6 1 2 3 4 -5 -6
# 6 1 -2 3 4 5 6
# 6 1 -2 -3 4 5 -6
# 6 -1 -2 3 -4 -5 -6
# 6 1 -2 3 -4 -5 -6
# 6 1 -2 -3 4 5 6
# 6 -1 -2 3 -4 -5 6
# 6 1 -2 3 -4 -5 6
# 6 1 2 3 4 5 -6
# 6 1 2 3 -4 -5 -6
# 6 -1 -2 3 4 -5 -6
# 6 1 2 3 4 5 6
# 6 1 2 3 -4 -5 6
# 6 -1 -2 -3 -4 5 -6
# 6 1 2 -3 -4 -5 -6

# %%
ordering = [5, 3, 1, 6, 4, 2]
mapping = {}
mapping[1] = "x2"
mapping[2] = "y2"
mapping[3] = "x1"
mapping[4] = "y1"
mapping[5] = "x0"
mapping[6] = "y0"
print(ordering)
a = BDD(f, ordering)
a
# Out:
# [5, 3, 1, 6, 4, 2]

# %%
a.displayGraph(mapping)
